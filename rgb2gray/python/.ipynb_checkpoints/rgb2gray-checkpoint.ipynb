# %%
import torch, os
import torchvision as tv
from torchvision import io
import matplotlib.pyplot as plt
# Out:
# Running cells with 'piptorch (Python 3.11.5)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n piptorch ipykernel --update-deps --force-reinstall'
